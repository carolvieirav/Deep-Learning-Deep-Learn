# %% [markdown]
# <a href="https://colab.research.google.com/github/carolvieirav/Deep-Learning-Deep-Learning/blob/main/Loading_Data_Deep_Learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import cv2
import random

# %% [markdown]
# ## Loop para acessar os arquivos dos diretórios

# %%
DATADIR = "/content/drive/MyDrive/Deep Learning Documents/kagglecatsanddogs_3367a.zip (Unzipped Files)/PetImages"

# %%
CATEGORIES =['Dog', 'Cat']

# %%
for category in CATEGORIES:
  path = os.path.join(DATADIR, category)
  for img in os.listdir(path):
    img_array = cv2.imread(os.path.join(path,img), cv2.IMREAD_GRAYSCALE)
    plt.imshow(img_array, cmap='gray')
    plt.show()
    break
  break

# %%
print(img_array)
# Out:
# [[255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  ...
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]]

# %% [markdown]
# ##Normalizando os Dados

# %%
IMG_SIZE = 50

new_array =  cv2.resize(img_array, (IMG_SIZE, IMG_SIZE))
plt.imshow(new_array, cmap = 'gray')
plt.show()

# %%
print(img_array)
# Out:
# [[255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  ...
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]]

# %% [markdown]
# ##Treinar Dados

# %%
training_data = np.empty([3,3])

def create_training_data():

  ''' Function that accesses files to train the data
  and transform the categories and binaries ones
  '''

  for category in CATEGORIES:
    path = os.path.join(DATADIR, category) # path to cats or dogs dir
    class_num = CATEGORIES.index(category) # transforming in binary categories
    for img in os.listdir(path):
      try: # identify broken images
        img_array = cv2.imread(os.path.join(path,img), cv2.IMREAD_GRAYSCALE)
        new_array =  cv2.resize(img_array, (IMG_SIZE, IMG_SIZE)) #normalizing
        trainig_data.append([new_array, class_num])
      except Exception as e:
        pass # passing

create_training_data()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-e7ac1adb918b> in <module>()
#      18         pass # passing
#      19
# ---> 20 create_training_data()
#
# <ipython-input-8-e7ac1adb918b> in create_training_data()
#      12     for img in os.listdir(path):
#      13       try: # identify broken images
# ---> 14         img_array = cv2.imread(os.path.join(path,img), cv2.IMREAD_GRAYSCALE)
#      15         new_array =  cv2.resize(img_array, (IMG_SIZE, IMG_SIZE)) #normalizing
#      16         trainig_data.append([new_array, class_num])
#
# KeyboardInterrupt:

# %%
print(len(training_data))

# %%
random.shuffle(training_data) #misturar os dados para a rede neural não ler uma
# categoria inteira de uma vez e lentificar o processamento de outra.

# %% [markdown]
# Finish the turorial:https://www.youtube.com/watch?v=j-3vuBynnOE&t=758s
